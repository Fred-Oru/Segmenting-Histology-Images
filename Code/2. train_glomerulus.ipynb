# %%
# %load_ext autoreload
# %autoreload 2

# %%
# initial training (20 epochs on Head + 20 epochs on Full)
# !python3 glomerulus.py train --dataset='../Data/glomerulus' --subset=train --weights=imagenet
# Out:
# 2020-06-03 06:24:38.956871: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# Using TensorFlow backend.
# Weights:  imagenet
# Dataset:  ../Data/glomerulus
# Subset:  train
# Logs:  /home/jupyter/Segmenting-Histology-Images/logs
#
# Configurations:
# BACKBONE                       resnet50
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     2
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        400
# DETECTION_MIN_CONFIDENCE       0
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 2
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  1024
# IMAGE_MIN_SCALE                0
# ...

# %%
# subsequent training (10 epochs on Full)
# !python3 glomerulus.py train --dataset='../Data/glomerulus' --subset=train --weights=last
# Out:
# 2020-04-06 08:45:22.385495: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# Using TensorFlow backend.
# Weights:  last
# Dataset:  ../Data/glomerulus
# Subset:  train
# Logs:  /home/jupyter/Segmenting-Histology-Images/logs
#
# Configurations:
# BACKBONE                       resnet50
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     2
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        400
# DETECTION_MIN_CONFIDENCE       0
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 2
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  1024
# IMAGE_MIN_SCALE                0
# ...
