# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# in case of an error on KMP 
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
# in case of 'Model' object has no attribute 'metrics_tensors.
pip install keras=="2.1.0"

# %%
# initial training (20 epochs on Head + 20 epochs on Full)
# !python3 -W ignore glomerulus.py train --dataset='/home/Fred/Data/glomerulus' --subset=train --weights=imagenet
# Out:
# Using TensorFlow backend.
# Weights:  imagenet
# Dataset:  /home/Fred/Data/glomerulus
# Subset:  train
# Logs:  /home/jupyter/Segmenting-Histology-Images/logs
#
# Configurations:
# BACKBONE                       resnet50
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        400
# DETECTION_MIN_CONFIDENCE       0
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  1024
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              crop
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# ...

# %%
# subsequent training (change NB_EPOCHS_FULL in glomerulus.py)
# !python3 -W ignore glomerulus.py train --dataset='/home/Fred/Data/glomerulus' --subset=train --weights=last
# Out:
# 2020-06-09 15:44:31.358170: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# Using TensorFlow backend.
# Weights:  last
# Dataset:  /home/Fred/Data/glomerulus
# Subset:  train
# Logs:  /home/jupyter/Segmenting-Histology-Images/logs
#
# Configurations:
# BACKBONE                       resnet50
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        400
# DETECTION_MIN_CONFIDENCE       0
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  512
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  512
# IMAGE_MIN_SCALE                0
# ...
