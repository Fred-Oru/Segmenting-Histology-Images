# %% [markdown]
# # Detect Bash command

# %%
# forces CPU usage
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %%
import time
t_start = time.time()

# !python3 glomerulus.py detect \
    --dataset='/home/Fred/Data/glomerulus' \
    --subset='run' \
    --weights='../logs/glomerulus20200603T0624/mask_rcnn_glomerulus_0050.h5' \
    --logs='../logs'

t_total = time.time() - t_start
print("Total time: {:.1f} seconds".format(t_total))
# Out:
# Using TensorFlow backend.
# Weights:  ../logs/glomerulus20200603T0624/mask_rcnn_glomerulus_0050.h5
# Dataset:  /home/Fred/Data/glomerulus
# Subset:  run
# Logs:  ../logs
#
# Configurations:
# BACKBONE                       resnet50
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        400
# DETECTION_MIN_CONFIDENCE       0
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  1024
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              pad64
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               200
# MEAN_PIXEL                     [190.6  175.39 205.24]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           glomerulus
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    64
# STEPS_PER_EPOCH                201
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           128
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               29
# WEIGHT_DECAY                   0.0001
#
#
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /home/jupyter/Segmenting-Histology-Images/mrcnn/model.py:341: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /home/jupyter/Segmenting-Histology-Images/mrcnn/model.py:399: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/jupyter/Segmenting-Histology-Images/mrcnn/model.py:423: calling crop_and_resize_v1 (from tensorflow.python.ops.image_ops_impl) with box_ind is deprecated and will be removed in a future version.
# Instructions for updating:
# box_ind is deprecated, use box_indices instead
# WARNING:tensorflow:From /home/jupyter/Segmenting-Histology-Images/mrcnn/model.py:758: The name tf.sets.set_intersection is deprecated. Please use tf.sets.intersection instead.
#
# WARNING:tensorflow:From /home/jupyter/Segmenting-Histology-Images/mrcnn/model.py:760: The name tf.sparse_tensor_to_dense is deprecated. Please use tf.sparse.to_dense instead.
#
# WARNING:tensorflow:From /home/jupyter/Segmenting-Histology-Images/mrcnn/model.py:772: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# Loading weights  ../logs/glomerulus20200603T0624/mask_rcnn_glomerulus_0050.h5
# 2020-06-08 15:19:07.870669: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2020-06-08 15:19:07.871001: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55fa717e1c10 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-06-08 15:19:07.871039: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-06-08 15:19:07.871334: I tensorflow/core/common_runtime/process_util.cc:136] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Re-starting from epoch 50
# Running on /home/Fred/Data/glomerulus
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# glomerulus.py:454: UserWarning: /home/jupyter/Segmenting-Histology-Images/results/run_detect_20200608T151912/C478 x10/masks/C478 x10-1.png is a low contrast image
#   skimage.io.imsave("{}/{}.png".format(mask_dir, mask_name),mask)
# glomerulus.py:454: UserWarning: /home/jupyter/Segmenting-Histology-Images/results/run_detect_20200608T151912/C478 x10/masks/C478 x10-2.png is a low contrast image
#   skimage.io.imsave("{}/{}.png".format(mask_dir, mask_name),mask)
# glomerulus.py:454: UserWarning: /home/jupyter/Segmenting-Histology-Images/results/run_detect_20200608T151912/C478 x10/masks/C478 x10-3.png is a low contrast image
#   skimage.io.imsave("{}/{}.png".format(mask_dir, mask_name),mask)
# glomerulus.py:454: UserWarning: /home/jupyter/Segmenting-Histology-Images/results/run_detect_20200608T151912/C350 x10/masks/C350 x10-1.png is a low contrast image
#   skimage.io.imsave("{}/{}.png".format(mask_dir, mask_name),mask)
# glomerulus.py:454: UserWarning: /home/jupyter/Segmenting-Histology-Images/results/run_detect_20200608T151912/C350 x10/masks/C350 x10-2.png is a low contrast image
#   skimage.io.imsave("{}/{}.png".format(mask_dir, mask_name),mask)
# glomerulus.py:454: UserWarning: /home/jupyter/Segmenting-Histology-Images/results/run_detect_20200608T151912/C350 x10/masks/C350 x10-3.png is a low contrast image
#   skimage.io.imsave("{}/{}.png".format(mask_dir, mask_name),mask)
# glomerulus.py:454: UserWarning: /home/jupyter/Segmenting-Histology-Images/results/run_detect_20200608T151912/C350 x10/masks/C350 x10-4.png is a low contrast image
#   skimage.io.imsave("{}/{}.png".format(mask_dir, mask_name),mask)
# glomerulus.py:454: UserWarning: /home/jupyter/Segmenting-Histology-Images/results/run_detect_20200608T151912/C350 x10/masks/C350 x10-5.png is a low contrast image
#   skimage.io.imsave("{}/{}.png".format(mask_dir, mask_name),mask)
#
# *** No instances to display ***
#
# Total time: 60.8 seconds
