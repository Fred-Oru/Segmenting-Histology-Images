# %% [markdown]
# # Detect Bash command

# %%
# Deactivate GPUs if any
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %%
import time
t_start = time.time()

# !python3 glomerulus.py detect \
    --dataset='../Data/glomerulus' \
    --subset='test/violet PAS' \
    --weights='../logs/glomerulus20200407T1219/mask_rcnn_glomerulus_0038.h5' \
    --logs='../logs'

t_total = time.time() - t_start
print("Total time: {:.1f} seconds".format(t_total))
# Out:
# 2020-04-07 14:09:35.037199: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# Using TensorFlow backend.
# Weights:  ../logs/glomerulus20200407T1219/mask_rcnn_glomerulus_0038.h5
# Dataset:  ../Data/glomerulus
# Subset:  test/violet PAS
# Logs:  ../logs
#
# Configurations:
# BACKBONE                       resnet50
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        400
# DETECTION_MIN_CONFIDENCE       0
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  1024
# IMAGE_MIN_SCALE                0
# ...
